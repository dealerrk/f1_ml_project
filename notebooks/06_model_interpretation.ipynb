# %% [markdown]
# ## Notebook 6: Model Interpretation & Feature Importance
#
# Objective
# Understand why the model makes its predictions by identifying which features have the biggest impact on lap time predictions.
# This is important because in a research paper it's not enough to say "Random Forest performed best." You also need to explain which factors influenced the prediction the most.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
import joblib

# %%
master_df = pd.read_csv("../data/processed/master_dataset.csv")
master_df.head()
# Out:
#   Driver             Team  LapNumber Compound  TyreLife  Stint  Position  \
# 0    VER  Red Bull Racing        1.0     SOFT       4.0    1.0       2.0
# 1    VER  Red Bull Racing        2.0     SOFT       5.0    1.0       2.0
# 2    VER  Red Bull Racing        3.0     SOFT       6.0    1.0       1.0
# 3    VER  Red Bull Racing        4.0     SOFT       7.0    1.0       1.0
# 4    VER  Red Bull Racing        5.0     SOFT       8.0    1.0       1.0
#
#    TrackStatus  LapTimeSeconds  FuelLoadApprox  StintProgress  \
# 0            1          83.186        0.984848          0.100
# 1            1          79.871        0.969697          0.125
# 2            1          79.364        0.954545          0.150
# 3            1          80.766        0.939394          0.175
# 4            1          80.827        0.924242          0.200
#
#    CompoundEncoded  FreshTyre  TyreAgeSquared
# 0                0          0            16.0
# 1                0          0            25.0
# ...

# %%
features = [
    "FuelLoadApprox",
    "StintProgress",
    "CompoundEncoded",
    "FreshTyre",
    "TyreAgeSquared"
]

X = master_df[features]
y = master_df["LapTimeSeconds"]

# %%
# training random forest again

rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %%
importance = pd.DataFrame({
    "Feature": features,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    "Importance",
    ascending=False
)

importance
# Out:
#            Feature  Importance
# 1    StintProgress    0.353035
# 0   FuelLoadApprox    0.316397
# 4   TyreAgeSquared    0.225830
# 3        FreshTyre    0.061758
# 2  CompoundEncoded    0.042980

# %%
# saving the feature importance

plt.figure(figsize=(8,5))

plt.bar(
    importance["Feature"],
    importance["Importance"]
)

plt.title("Random Forest Feature Importance")
plt.xlabel("Features")
plt.ylabel("Importance")

plt.xticks(rotation=30)

plt.tight_layout()

plt.savefig("../outputs/figures/feature_importance.png", dpi=300)

plt.show()

# %%
from pathlib import Path

# Create folder if it doesn't exist
Path("../outputs/tables").mkdir(parents=True, exist_ok=True)

# Save feature importance table
importance.to_csv(
    "../outputs/tables/feature_importance.csv",
    index=False
)

print("Feature importance saved successfully!")
importance
# Out:
# Feature importance saved successfully!
#            Feature  Importance
# 1    StintProgress    0.353035
# 0   FuelLoadApprox    0.316397
# 4   TyreAgeSquared    0.225830
# 3        FreshTyre    0.061758
# 2  CompoundEncoded    0.042980
