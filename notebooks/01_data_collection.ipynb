# %%
import os
import fastf1

os.makedirs('f1_cache', exist_ok=True)
fastf1.Cache.enable_cache('f1_cache')

# %% [markdown]
# # Formula 1 Race Strategy Intelligence System
#
# ## Notebook 1: Data Collection
#
# Objective:
# Collect lap data, telemetry, weather data, and session information from FastF1 for selected Formula 1 races.

# %%
import pandas as pd
import numpy as np

# %%
# loading the first race

session = fastf1.get_session(2024, "Bahrain", "R")
session.load()
session
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # loading the first race
#       2
# ----> 3 session = fastf1.get_session(2024, "Bahrain", "R")
#       4 session.load()
#       5 session
#
# NameError: name 'fastf1' is not defined

# %%
# getting the lap data

laps = session.laps
print(laps.shape)
laps.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 # getting the lap data
#       2
# ----> 3 laps = session.laps
#       4 print(laps.shape)
#       5 laps.head()
#
# NameError: name 'session' is not defined

# %%
# exploring the columns

print(laps.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # exploring the columns
#       2
# ----> 3 print(laps.columns.tolist())
#
# NameError: name 'laps' is not defined

# %%
# keeping only the useful columns

lap_data = laps[
    [
        "Driver",
        "LapNumber",
        "LapTime",
        "Compound",
        "TyreLife",
        "Stint",
        "Position"
    ]
]
lap_data.head()
# Out:
#   Driver  LapNumber                LapTime Compound  TyreLife  Stint  Position
# 0    VER        1.0 0 days 00:01:37.284000     SOFT       4.0    1.0       1.0
# 1    VER        2.0 0 days 00:01:36.296000     SOFT       5.0    1.0       1.0
# 2    VER        3.0 0 days 00:01:36.753000     SOFT       6.0    1.0       1.0
# 3    VER        4.0 0 days 00:01:36.647000     SOFT       7.0    1.0       1.0
# 4    VER        5.0 0 days 00:01:37.173000     SOFT       8.0    1.0       1.0

# %%
# checking the null values or the missing values

print(lap_data.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # checking the null values or the missing values
#       2
# ----> 3 print(lap_data.isnull().sum())
#
# NameError: name 'lap_data' is not defined

# %%
# saving the dataset we have obtained

import os
os.makedirs("../data/raw", exist_ok=True)
lap_data.to_csv(
    "../data/raw/bahrain_2024_laps.csv",
    index=False
)
print("Dataset saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # saving the dataset we have obtained
#       2
#       3 import os
#       4 os.makedirs("../data/raw", exist_ok=True)
# ----> 5 lap_data.to_csv(
#       6     "../data/raw/bahrain_2024_laps.csv",
#       7     index=False
#       8 )
#
# NameError: name 'lap_data' is not defined
